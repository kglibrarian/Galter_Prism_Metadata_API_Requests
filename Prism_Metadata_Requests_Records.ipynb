# %%
# Dependencies
import requests
from requests.exceptions import HTTPError
import json
import pandas as pd
import numpy as np
import re
import io
from config import api_key_prism
from collections import OrderedDict
from pandas.io.json import json_normalize  
import time 
import urllib.request
from pprint import pprint

# %%
## API request from Prism

## url = 'https://vtfsmghslrepo02.fsm.northwestern.edu/api/records'
## url = 'https://prism-staging.fsm.northwestern.edu/api/records'
## url = 'https://prism-staging.fsm.northwestern.edu/api/records/vfjy1-jhr35'
url = 'https://prism.northwestern.edu/api/records?'
# url = 'https://prism.northwestern.edu/api/communities?'
# records = 100
# size = 100 - total
# 'size': 100, 
# 'offset': 100,
#         'page': 2, 
#         'status': 
#         'published', 
#         'sort': 'bestmatch', 
params={

        'all_versions': 'false', 
        'access_token': api_key_prism
       }

response = requests.get(url, params=params)


print(response.url)
print(response.status_code)

# response_json = response.json()['hits']
response_json = response.json()
pprint(response_json)
print(json.dumps(response_json, indent=4, sort_keys=True))
# Out:
# https://prism.northwestern.edu/api/records?all_versions=false&access_token=mgS5In0TwRjbTbfr1Z72Pbj8bgAFVE4kMrOMNkw0LOLJgwzJK9sHcoOwColI
# 200
# {'aggregations': {'access_status': {'buckets': [{'doc_count': 5834,
#                                                  'is_selected': False,
#                                                  'key': 'open',
#                                                  'label': 'Open'},
#                                                 {'doc_count': 2,
#                                                  'is_selected': False,
#                                                  'key': 'restricted',
#                                                  'label': 'Restricted'}],
#                                     'label': 'Access status'},
#                   'resource_type': {'buckets': [{'doc_count': 3906,
#                                                  'inner': {'buckets': [{'doc_count': 3858,
#                                                                         'is_selected': False,
#                                                                         'key': 'article-journal_article',
#                                                                         'label': 'Journal '
#                                                                                  'Article'},
#                                                                        {'doc_count': 24,
#                                                                         'is_selected': False,
#                                                                         'key': 'article-other_article',
#                                                                         'label': 'Other '
#                                                                                  'Article'},
#                                                                        {'doc_count': 16,
#                                                                         'is_selected': False,
#                                                                         'key': 'article-review',
#                                                                         'label': 'Review'},
#                                                                        {'doc_count': 6,
#                                                                         'is_selected': False,
#                                                                         'key': 'article-case_report',
#                                                                         'label': 'Case '
#                                                                                  'Report'},
#                                                                        {'doc_count': 1,
#                                                                         'is_selected': False,
#                                                                         'key': 'article-editorial',
#                                                                         'label': 'Editorial'},
#                                                                        {'doc_count': 1,
#                                                                         'is_selected': False,
#                                                                         'key': 'article-evaluation_study',
#                                                                         'label': 'Evaluation '
#                                                                                  'Study'}]},
#                                                  'is_selected': False,
#                                                  'key': 'article',
#                                                  'label': 'Articles'},
#                                                 {'doc_count': 540,
#                                                  'inner': {'buckets': [{'doc_count': 433,
#                                                                         'is_selected': False,
#                                                                         'key': 'image-photograph',
#                                                                         'label': 'Photograph'},
#                                                                        {'doc_count': 59,
#                                                                         'is_selected': False,
#                                                                         'key': 'image-pictorial_work',
#                                                                         'label': 'Pictorial '
#                                                                                  'Work'},
#                                                                        {'doc_count': 35,
#                                                                         'is_selected': False,
#                                                                         'key': 'image-portrait',
#                                                                         'label': 'Portrait'},
#                                                                        {'doc_count': 7,
#                                                                         'is_selected': False,
#                                                                         'key': 'image-architectural_drawing',
#                                                                         'label': 'Architectural '
#                                                                                  'Drawing'},
#                                                                        {'doc_count': 4,
#                                                                         'is_selected': False,
#                                                                         'key': 'image-chart',
#                                                                         'label': 'Chart'},
#                                                                        {'doc_count': 1,
#                                                                         'is_selected': False,
#                                                                         'key': 'image-drawing',
#                                                                         'label': 'Drawing'},
#                                                                        {'doc_count': 1,
#                                                                         'is_selected': False,
#                                                                         'key': 'image-map',
#                                                                         'label': 'Map'}]},
#                                                  'is_selected': False,
#                                                  'key': 'image',
#                                                  'label': 'Images'},
#                                                 {'doc_count': 451,
#                                                  'inner': {'buckets': [{'doc_count': 167,
#                                                                         'is_selected': False,
#                                                                         'key': 'text-letter',
#                                                                         'label': 'Letter'},
#                                                                        {'doc_count': 83,
#                                                                         'is_selected': False,
#                                                                         'key': 'text-report',
#                                                                         'label': 'Report'},
#                                                                        {'doc_count': 62,
#                                                                         'is_selected': False,
#                                                                         'key': 'text-guideline',
#                                                                         'label': 'Guideline'},
#                                                                        {'doc_count': 53,
#                                                                         'is_selected': False,
#                                                                         'key': 'text-manuscript',
#                                                                         'label': 'Manuscript'},
#                                                                        {'doc_count': 31,
#                                                                         'is_selected': False,
#                                                                         'key': 'text-form',
#                                                                         'label': 'Form'},
#                                                                        {'doc_count': 22,
#                                                                         'is_selected': False,
#                                                                         'key': 'text-program',
#                                                                         'label': 'Program'},
#                                                                        {'doc_count': 18,
#                                                                         'is_selected': False,
#                                                                         'key': 'text-preprint',
#                                                                         'label': 'Preprint'},
#                                                                        {'doc_count': 6,
#                                                                         'is_selected': False,
#                                                                         'key': 'text-technical_documentation',
#                                                                         'label': 'Technical '
#                                                                                  'Documentation'},
#                                                                        {'doc_count': 3,
#                                                                         'is_selected': False,
#                                                                         'key': 'text-resource_guide',
#                                                                         'label': 'Resource '
#                                                                                  'Guide'},
#                                                                        {'doc_count': 2,
#                                                                         'is_selected': False,
#                                                                         'key': 'text-bibliography',
#                                                                         'label': 'Bibliography'}]},
#                                                  'is_selected': False,
#                                                  'key': 'text',
#                                                  'label': 'Text Resources'},
#                                                 {'doc_count': 143,
#                                                  'inner': {'buckets': [{'doc_count': 90,
#                                                                         'is_selected': False,
#                                                                         'key': 'conference-conference_presentation',
#                                                                         'label': 'Conference '
#                                                                                  'Presentation'},
#                                                                        {'doc_count': 36,
#                                                                         'is_selected': False,
#                                                                         'key': 'conference-conference_poster',
#                                                                         'label': 'Conference '
#                                                                                  'Poster'},
#                                                                        {'doc_count': 13,
#                                                                         'is_selected': False,
#                                                                         'key': 'conference-congress',
#                                                                         'label': 'Congress'},
#                                                                        {'doc_count': 2,
#                                                                         'is_selected': False,
#                                                                         'key': 'conference-conference_paper',
#                                                                         'label': 'Conference '
#                                                                                  'Paper'},
#                                                                        {'doc_count': 2,
#                                                                         'is_selected': False,
#                                                                         'key': 'conference-conference_proceeding',
#                                                                         'label': 'Conference '
#                                                                                  'Proceeding'}]},
#                                                  'is_selected': False,
#                                                  'key': 'conference',
#                                                  'label': 'Conference Objects'},
#                                                 {'doc_count': 138,
#                                                  'inner': {'buckets': [{'doc_count': 78,
#                                                                         'is_selected': False,
#                                                                         'key': 'study_documentation-study_design',
#                                                                         'label': 'Study '
#                                                                                  'Design'},
#                                                                        {'doc_count': 59,
#                                                                         'is_selected': False,
#                                                                         'key': 'study_documentation-statistics',
#                                                                         'label': 'Statistics'},
#                                                                        {'doc_count': 1,
#                                                                         'is_selected': False,
#                                                                         'key': 'study_documentation-proposal',
#                                                                         'label': 'Research '
#                                                                                  'Proposal'}]},
#                                                  'is_selected': False,
#                                                  'key': 'study_documentation',
#                                                  'label': 'Study '
#                                                           'Documentation'},
#                                                 {'doc_count': 129,
#                                                  'inner': {'buckets': [{'doc_count': 82,
#                                                                         'is_selected': False,
#                                                                         'key': 'learning-presentation',
#                                                                         'label': 'Presentation'},
#                                                                        {'doc_count': 29,
#                                                                         'is_selected': False,
#                                                                         'key': 'learning-lecture',
#                                                                         'label': 'Lecture'},
#                                                                        {'doc_count': 15,
#                                                                         'is_selected': False,
#                                                                         'key': 'learning-instructional-film-and-video',
#                                                                         'label': 'Instructional '
#                                                                                  'Film '
#                                                                                  'and '
#                                                                                  'Video'},
#                                                                        {'doc_count': 2,
#                                                                         'is_selected': False,
#                                                                         'key': 'learning-lesson_plan',
#                                                                         'label': 'Lesson '
#                                                                                  'Plan'},
#                                                                        {'doc_count': 1,
#                                                                         'is_selected': False,
#                                                                         'key': 'learning-problems_and_exercises',
#                                                                         'label': 'Problems '
#                                                                                  'and '
#                                                                                  'Exercises'}]},
#                                                  'is_selected': False,
#                                                  'key': 'learning',
#                                                  'label': 'Learning Objects'},
#                                                 {'doc_count': 103,
#                                                  'inner': {'buckets': []},
#                                                  'is_selected': False,
#                                                  'key': 'dataset',
#                                                  'label': 'Dataset'},
#                                                 {'doc_count': 99,
#                                                  'inner': {'buckets': [{'doc_count': 97,
#                                                                         'is_selected': False,
#                                                                         'key': 'thesis-masters_thesis',
#                                                                         'label': 'Masters '
#                                                                                  'Thesis'},
#                                                                        {'doc_count': 2,
#                                                                         'is_selected': False,
#                                                                         'key': 'thesis-doctoral_thesis',
#                                                                         'label': 'Doctoral '
#                                                                                  'Thesis'}]},
#                                                  'is_selected': False,
#                                                  'key': 'thesis',
#                                                  'label': 'Theses and '
#                                                           'Dissertations'},
#                                                 {'doc_count': 92,
#                                                  'inner': {'buckets': [{'doc_count': 70,
#                                                                         'is_selected': False,
#                                                                         'key': 'book-biography',
#                                                                         'label': 'Biography'},
#                                                                        {'doc_count': 14,
#                                                                         'is_selected': False,
#                                                                         'key': 'book-handbook',
#                                                                         'label': 'Handbook'},
#                                                                        {'doc_count': 4,
#                                                                         'is_selected': False,
#                                                                         'key': 'book-book',
#                                                                         'label': 'Book'},
#                                                                        {'doc_count': 3,
#                                                                         'is_selected': False,
#                                                                         'key': 'book-book_part',
#                                                                         'label': 'Book '
#                                                                                  'Part'},
#                                                                        {'doc_count': 1,
#                                                                         'is_selected': False,
#                                                                         'key': 'book-catalog',
#                                                                         'label': 'Catalog'}]},
#                                                  'is_selected': False,
#                                                  'key': 'book',
#                                                  'label': 'Books'},
#                                                 {'doc_count': 72,
#                                                  'inner': {'buckets': [{'doc_count': 72,
#                                                                         'is_selected': False,
#                                                                         'key': 'periodical-newsletter',
#                                                                         'label': 'Newsletter'}]},
#                                                  'is_selected': False,
#                                                  'key': 'periodical',
#                                                  'label': 'Periodicals'}],
#                                     'label': 'Resource types'},
#                   'subject_nested': {'buckets': [{'doc_count': 5459,
#                                                   'inner': {'buckets': [{'doc_count': 3764,
#                                                                          'is_selected': False,
#                                                                          'key': 'Child',
#                                                                          'label': 'Child'},
#                                                                         {'doc_count': 3755,
#                                                                          'is_selected': False,
#                                                                          'key': 'Pediatrics',
#                                                                          'label': 'Pediatrics'},
#                                                                         {'doc_count': 3753,
#                                                                          'is_selected': False,
#                                                                          'key': 'Infant',
#                                                                          'label': 'Infant'},
#                                                                         {'doc_count': 3751,
#                                                                          'is_selected': False,
#                                                                          'key': 'Neurosurgery',
#                                                                          'label': 'Neurosurgery'},
#                                                                         {'doc_count': 3749,
#                                                                          'is_selected': False,
#                                                                          'key': 'Neurology',
#                                                                          'label': 'Neurology'},
#                                                                         {'doc_count': 3746,
#                                                                          'is_selected': False,
#                                                                          'key': 'Child '
#                                                                                 'Development',
#                                                                          'label': 'Child '
#                                                                                   'Development'},
#                                                                         {'doc_count': 3745,
#                                                                          'is_selected': False,
#                                                                          'key': 'Brain '
#                                                                                 'Diseases',
#                                                                          'label': 'Brain '
#                                                                                   'Diseases'},
#                                                                         {'doc_count': 3745,
#                                                                          'is_selected': False,
#                                                                          'key': 'Nervous '
#                                                                                 'System '
#                                                                                 'Diseases',
#                                                                          'label': 'Nervous '
#                                                                                   'System '
#                                                                                   'Diseases'},
#                                                                         {'doc_count': 556,
#                                                                          'is_selected': False,
#                                                                          'key': 'World '
#                                                                                 'War '
#                                                                                 'II',
#                                                                          'label': 'World '
#                                                                                   'War '
#                                                                                   'II'},
#                                                                         {'doc_count': 533,
#                                                                          'is_selected': False,
#                                                                          'key': '12th '
#                                                                                 'General '
#                                                                                 'Hospital',
#                                                                          'label': '12th '
#                                                                                   'General '
#                                                                                   'Hospital'}]},
#                                                   'is_selected': False,
#                                                   'key': 'MeSH',
#                                                   'label': 'MeSH'},
#                                                  {'doc_count': 942,
#                                                   'inner': {'buckets': [{'doc_count': 527,
#                                                                          'is_selected': False,
#                                                                          'key': 'World '
#                                                                                 'War '
#                                                                                 'II',
#                                                                          'label': 'World '
#                                                                                   'War '
#                                                                                   'II'},
#                                                                         {'doc_count': 511,
#                                                                          'is_selected': False,
#                                                                          'key': '12th '
#                                                                                 'General '
#                                                                                 'Hospital',
#                                                                          'label': '12th '
#                                                                                   'General '
#                                                                                   'Hospital'},
#                                                                         {'doc_count': 219,
#                                                                          'is_selected': False,
#                                                                          'key': 'World '
#                                                                                 'War, '
#                                                                                 '1939-1945',
#                                                                          'label': 'World '
#                                                                                   'War, '
#                                                                                   '1939-1945'},
#                                                                         {'doc_count': 214,
#                                                                          'is_selected': False,
#                                                                          'key': 'Northwestern '
#                                                                                 'University',
#                                                                          'label': 'Northwestern '
#                                                                                   'University'},
#                                                                         {'doc_count': 188,
#                                                                          'is_selected': False,
#                                                                          'key': 'ʻAyn '
#                                                                                 'al-Turk '
#                                                                                 '(Algeria)',
#                                                                          'label': 'ʻAyn '
#                                                                                   'al-Turk '
#                                                                                   '(Algeria)'},
#                                                                         {'doc_count': 184,
#                                                                          'is_selected': False,
#                                                                          'key': 'Military '
#                                                                                 'Personnel',
#                                                                          'label': 'Military '
#                                                                                   'Personnel'},
#                                                                         {'doc_count': 125,
#                                                                          'is_selected': False,
#                                                                          'key': 'Chicago '
#                                                                                 '(Ill.)',
#                                                                          'label': 'Chicago '
#                                                                                   '(Ill.)'},
#                                                                         {'doc_count': 119,
#                                                                          'is_selected': False,
#                                                                          'key': 'Hospitals, '
#                                                                                 'Military',
#                                                                          'label': 'Hospitals, '
#                                                                                   'Military'},
#                                                                         {'doc_count': 88,
#                                                                          'is_selected': False,
#                                                                          'key': 'Rome '
#                                                                                 '(Italy)',
#                                                                          'label': 'Rome '
#                                                                                   '(Italy)'},
#                                                                         {'doc_count': 76,
#                                                                          'is_selected': False,
#                                                                          'key': 'Fort '
#                                                                                 'Custer '
#                                                                                 '(Mich.)',
#                                                                          'label': 'Fort '
#                                                                                   'Custer '
#                                                                                   '(Mich.)'}]},
#                                                   'is_selected': False,
#                                                   'key': 'LCNAF',
#                                                   'label': 'LCNAF'},
#                                                  {'doc_count': 745,
#                                                   'inner': {'buckets': [{'doc_count': 333,
#                                                                          'is_selected': False,
#                                                                          'key': '12th '
#                                                                                 'General '
#                                                                                 'Hospital',
#                                                                          'label': '12th '
#                                                                                   'General '
#                                                                                   'Hospital'},
#                                                                         {'doc_count': 317,
#                                                                          'is_selected': False,
#                                                                          'key': 'World '
#                                                                                 'War '
#                                                                                 'II',
#                                                                          'label': 'World '
#                                                                                   'War '
#                                                                                   'II'},
#                                                                         {'doc_count': 225,
#                                                                          'is_selected': False,
#                                                                          'key': 'World '
#                                                                                 'War, '
#                                                                                 '1939-1945',
#                                                                          'label': 'World '
#                                                                                   'War, '
#                                                                                   '1939-1945'},
#                                                                         {'doc_count': 112,
#                                                                          'is_selected': False,
#                                                                          'key': 'Northwestern '
#                                                                                 'University',
#                                                                          'label': 'Northwestern '
#                                                                                   'University'},
#                                                                         {'doc_count': 108,
#                                                                          'is_selected': False,
#                                                                          'key': 'Military '
#                                                                                 'Personnel',
#                                                                          'label': 'Military '
#                                                                                   'Personnel'},
#                                                                         {'doc_count': 100,
#                                                                          'is_selected': False,
#                                                                          'key': 'Libraries, '
#                                                                                 'Medical',
#                                                                          'label': 'Libraries, '
#                                                                                   'Medical'},
#                                                                         {'doc_count': 89,
#                                                                          'is_selected': False,
#                                                                          'key': 'ʻAyn '
#                                                                                 'al-Turk '
#                                                                                 '(Algeria)',
#                                                                          'label': 'ʻAyn '
#                                                                                   'al-Turk '
#                                                                                   '(Algeria)'},
#                                                                         {'doc_count': 74,
#                                                                          'is_selected': False,
#                                                                          'key': 'Chicago '
#                                                                                 '(Ill.)',
#                                                                          'label': 'Chicago '
#                                                                                   '(Ill.)'},
#                                                                         {'doc_count': 68,
#                                                                          'is_selected': False,
#                                                                          'key': 'Training',
#                                                                          'label': 'Training'},
#                                                                         {'doc_count': 59,
#                                                                          'is_selected': False,
#                                                                          'key': 'Fort '
#                                                                                 'Custer '
#                                                                                 '(Mich.)',
#                                                                          'label': 'Fort '
#                                                                                   'Custer '
#                                                                                   '(Mich.)'}]},
#                                                   'is_selected': False,
#                                                   'key': 'LCSH',
#                                                   'label': 'LCSH'}],
#                                      'label': 'Subjects'}},
#  'hits': {'hits': [{'access': {'embargo': {'active': False, 'reason': None},
#                                'files': 'public',
#                                'record': 'public',
#                                'status': 'open'},
#                     'created': '2024-05-06T04:00:14.877901+00:00',
#                     'custom_fields': {},
#                     'files': {'enabled': True, 'order': []},
#                     'id': 'n0xcr-85a45',
#                     'is_draft': False,
#                     'is_published': True,
#                     'links': {'access_links': 'https://prism.northwestern.edu/api/records/n0xcr-85a45/access/links',
#                               'archive': 'https://prism.northwestern.edu/api/records/n0xcr-85a45/files-archive',
#                               'doi': 'https://doi.org/10.18131/n0xcr-85a45',
#                               'draft': 'https://prism.northwestern.edu/api/records/n0xcr-85a45/draft',
#                               'files': 'https://prism.northwestern.edu/api/records/n0xcr-85a45/files',
#                               'latest': 'https://prism.northwestern.edu/api/records/n0xcr-85a45/versions/latest',
#                               'latest_html': 'https://prism.northwestern.edu/records/n0xcr-85a45/latest',
#                               'reserve_doi': 'https://prism.northwestern.edu/api/records/n0xcr-85a45/draft/pids/doi',
#                               'self': 'https://prism.northwestern.edu/api/records/n0xcr-85a45',
#                               'self_doi': 'https://prism.northwestern.edu/doi/10.18131/n0xcr-85a45',
#                               'self_html': 'https://prism.northwestern.edu/records/n0xcr-85a45',
#                               'self_iiif_manifest': 'https://prism.northwestern.edu/api/iiif/record:n0xcr-85a45/manifest',
#                               'self_iiif_sequence': 'https://prism.northwestern.edu/api/iiif/record:n0xcr-85a45/sequence/default',
#                               'versions': 'https://prism.northwestern.edu/api/records/n0xcr-85a45/versions'},
#                     'metadata': {'creators': [{'affiliations': [{'id': '000e0be47',
#                                                                  'name': 'Northwestern '
#                                                                          'University'}],
#                                                'person_or_org': {'family_name': 'Cong',
#                                                                  'given_name': 'Lixuan',
#                                                                  'name': 'Cong, '
#                                                                          'Lixuan',
#                                                                  'type': 'personal'},
#                                                'role': {'id': 'role-researcher',
#                                                         'title': {'en': 'Researcher '
#                                                                         'role'}}},
#                                               {'person_or_org': {'family_name': 'Walubita',
#                                                                  'given_name': 'Tubanji',
#                                                                  'name': 'Walubita, '
#                                                                          'Tubanji',
#                                                                  'type': 'personal'}},
#                                               {'person_or_org': {'family_name': 'Epstein',
#                                                                  'given_name': 'Richard',
#                                                                  'name': 'Epstein, '
#                                                                          'Richard',
#                                                                  'type': 'personal'}},
#                                               {'person_or_org': {'family_name': 'Berry',
#                                                                  'given_name': 'Andrew',
#                                                                  'name': 'Berry, '
#                                                                          'Andrew',
#                                                                  'type': 'personal'}},
#                                               {'person_or_org': {'family_name': 'Johnson',
#                                                                  'given_name': 'Julie',
#                                                                  'name': 'Johnson, '
#                                                                          'Julie',
#                                                                  'type': 'personal'}}],
#                                  'description': '<p>User Centered Design (UCD) '
#                                                 'applies an iterative design '
#                                                 'process in which the designer '
#                                                 'develops high-quality and '
#                                                 'usable products by '
#                                                 "understanding user's "
#                                                 'needs.&nbsp;In healthcare, '
#                                                 'UCD has been used to '
#                                                 "prioritize patients' and "
#                                                 "healthcare professionals' "
#                                                 'needs and experiences and '
#                                                 'help design interventions '
#                                                 'that are easy to understand '
#                                                 'and use.&nbsp;</p><p>Within '
#                                                 'the design phases of UCD, '
#                                                 'prototypes are widely '
#                                                 'recognized as a core means of '
#                                                 'exploring and testing design '
#                                                 'products.&nbsp;Efficient '
#                                                 'prototyping methods are '
#                                                 'needed especially in adult '
#                                                 'critical care when UCD is '
#                                                 'applied in a fast-paced and '
#                                                 'challenging environment where '
# ...
#                             "type": {
#                                 "id": "abstract",
#                                 "title": {
#                                     "en": "Abstract"
#                                 }
#                             }
#                         },
#                         {
#                             "description": "original_citation: Hasan MM, Zhang M, Beal M, et al. An umbrella review comparing computer-assisted and conventional total joint arthroplasty: quality assessment and summaryof evidence. BMJ Surg Interv Health Technologies2020;2:e000016. doi:10.1136/bmjsit-2019-000016",
#                             "type": {
#                                 "id": "other",
#                                 "title": {
#                                     "en": "Other"
#                                 }
#                             }
#                         }
#                     ],
#                     "creators": [
#                         {
#                             "person_or_org": {
#                                 "family_name": "Hasan",
#                                 "given_name": "Mohamed Mosaad Ismail",
#                                 "name": "Hasan, Mohamed Mosaad Ismail",
#                                 "type": "personal"
#                             }
#                         },
#                         {
#                             "person_or_org": {
#                                 "family_name": "Zhang",
#                                 "given_name": "Manrui",
#                                 "name": "Zhang, Manrui",
#                                 "type": "personal"
#                             }
#                         },
#                         {
#                             "person_or_org": {
#                                 "family_name": "Beal",
#                                 "given_name": "Matthew",
#                                 "name": "Beal, Matthew",
#                                 "type": "personal"
#                             }
#                         },
#                         {
#                             "person_or_org": {
#                                 "family_name": "Ghomrawi",
#                                 "given_name": "Hassan",
#                                 "name": "Ghomrawi, Hassan",
#                                 "type": "personal"
#                             }
#                         }
#                     ],
#                     "dates": [
#                         {
#                             "date": "2020",
#                             "description": "When the item was originally created.",
#                             "type": {
#                                 "id": "created",
#                                 "title": {
#                                     "de": "Erstellt",
#                                     "en": "Created"
#                                 }
#                             }
#                         }
#                     ],
#                     "formats": [
#                         "application/pdf"
#                     ],
#                     "languages": [
#                         {
#                             "id": "eng",
#                             "title": {
#                                 "en": "English"
#                             }
#                         }
#                     ],
#                     "publication_date": "2020",
#                     "publisher": "BMJ Journals",
#                     "related_identifiers": [
#                         {
#                             "identifier": "10.1136/ bmjsit-2019-000016",
#                             "relation_type": {
#                                 "id": "isrelatedto",
#                                 "title": {
#                                     "en": "Is related to"
#                                 }
#                             },
#                             "scheme": "doi"
#                         }
#                     ],
#                     "resource_type": {
#                         "id": "article-review",
#                         "title": {
#                             "en": "Review"
#                         }
#                     },
#                     "rights": [
#                         {
#                             "description": {
#                                 "en": ""
#                             },
#                             "id": "cc-by-nc-3.0-us",
#                             "props": {
#                                 "scheme": "custom",
#                                 "url": "https://creativecommons.org/licenses/by-nc/3.0/us/legalcode"
#                             },
#                             "title": {
#                                 "en": "Creative Commons Attribution Non Commercial 3.0 United States"
#                             }
#                         }
#                     ],
#                     "sizes": [
#                         "14 pages"
#                     ],
#                     "subjects": [
#                         {
#                             "subject": "overview of systematic review"
#                         },
#                         {
#                             "subject": "total joint arthroplasty"
#                         },
#                         {
#                             "subject": "computer-assisted surgery"
#                         },
#                         {
#                             "subject": "meta-analysis"
#                         },
#                         {
#                             "id": "https://id.nlm.nih.gov/mesh/D019645",
#                             "scheme": "MeSH",
#                             "subject": "Arthroplasty, Replacement, Knee"
#                         },
#                         {
#                             "id": "https://id.nlm.nih.gov/mesh/D019644",
#                             "scheme": "MeSH",
#                             "subject": "Arthroplasty, Replacement, Hip"
#                         },
#                         {
#                             "id": "https://id.nlm.nih.gov/mesh/D025321",
#                             "scheme": "MeSH",
#                             "subject": "Surgery, Computer-Assisted"
#                         }
#                     ],
#                     "title": "An umbrella review comparing computer-assisted and conventional total joint arthroplasty: quality assessment and summary of evidence",
#                     "version": "v1.0.0"
#                 },
#                 "parent": {
#                     "communities": {},
#                     "id": "4pxky-vh482"
#                 },
#                 "pids": {
#                     "doi": {
#                         "identifier": "10.1136/bmjsit-2019-000016",
#                         "provider": "external"
#                     },
#                     "oai": {
#                         "identifier": "oai:prism.northwestern.edu:4gqbz-9m180",
#                         "provider": "oai"
#                     }
#                 },
#                 "revision_id": 5,
#                 "status": "published",
#                 "updated": "2024-04-05T21:10:18.627959+00:00",
#                 "versions": {
#                     "index": 1,
#                     "is_latest": true
#                 }
#             },
#             {
#                 "access": {
#                     "embargo": {
#                         "active": false,
#                         "reason": null
#                     },
#                     "files": "public",
#                     "record": "public",
#                     "status": "open"
#                 },
#                 "created": "2023-03-30T15:30:22.723053+00:00",
#                 "custom_fields": {},
#                 "files": {
#                     "enabled": true,
#                     "order": []
#                 },
#                 "id": "ptmg4-xdg64",
#                 "is_draft": false,
#                 "is_published": true,
#                 "links": {
#                     "access_links": "https://prism.northwestern.edu/api/records/ptmg4-xdg64/access/links",
#                     "archive": "https://prism.northwestern.edu/api/records/ptmg4-xdg64/files-archive",
#                     "doi": "https://doi.org/10.1007/978-3-319-16555-4_3",
#                     "draft": "https://prism.northwestern.edu/api/records/ptmg4-xdg64/draft",
#                     "files": "https://prism.northwestern.edu/api/records/ptmg4-xdg64/files",
#                     "latest": "https://prism.northwestern.edu/api/records/ptmg4-xdg64/versions/latest",
#                     "latest_html": "https://prism.northwestern.edu/records/ptmg4-xdg64/latest",
#                     "reserve_doi": "https://prism.northwestern.edu/api/records/ptmg4-xdg64/draft/pids/doi",
#                     "self": "https://prism.northwestern.edu/api/records/ptmg4-xdg64",
#                     "self_doi": "https://prism.northwestern.edu/doi/10.1007/978-3-319-16555-4_3",
#                     "self_html": "https://prism.northwestern.edu/records/ptmg4-xdg64",
#                     "self_iiif_manifest": "https://prism.northwestern.edu/api/iiif/record:ptmg4-xdg64/manifest",
#                     "self_iiif_sequence": "https://prism.northwestern.edu/api/iiif/record:ptmg4-xdg64/sequence/default",
#                     "versions": "https://prism.northwestern.edu/api/records/ptmg4-xdg64/versions"
#                 },
#                 "metadata": {
#                     "creators": [
#                         {
#                             "person_or_org": {
#                                 "family_name": "Nandwana",
#                                 "given_name": "Vikas",
#                                 "name": "Nandwana, Vikas",
#                                 "type": "personal"
#                             }
#                         }
#                     ],
#                     "dates": [
#                         {
#                             "date": "2015",
#                             "description": "When the item was originally created.",
#                             "type": {
#                                 "id": "created",
#                                 "title": {
#                                     "de": "Erstellt",
#                                     "en": "Created"
#                                 }
#                             }
#                         }
#                     ],
#                     "formats": [
#                         "application/pdf"
#                     ],
#                     "identifiers": [
#                         {
#                             "identifier": "ark:/c8131/g3rb2v",
#                             "scheme": "ark"
#                         }
#                     ],
#                     "languages": [
#                         {
#                             "id": "eng",
#                             "title": {
#                                 "en": "English"
#                             }
#                         }
#                     ],
#                     "publication_date": "2015",
#                     "publisher": "Springer International Publishing",
#                     "resource_type": {
#                         "id": "book-book_part",
#                         "title": {
#                             "en": "Book Part"
#                         }
#                     },
#                     "rights": [
#                         {
#                             "description": {
#                                 "en": "The copyright holder is not providing a license for re-use. The copyright holder reserves, or holds for its own use, all the rights provided by copyright law."
#                             },
#                             "id": "galter-arr-1.0",
#                             "props": {
#                                 "scheme": "custom",
#                                 "url": "https://galter.northwestern.edu/galter-arr-1.0"
#                             },
#                             "title": {
#                                 "en": "All Rights Reserved"
#                             }
#                         }
#                     ],
#                     "sizes": [
#                         "33 pages"
#                     ],
#                     "subjects": [
#                         {
#                             "subject": "Magnetic Nanoparticles, Magnetic Nanostructures, Theranostics, Non-invasive, Drug Delivery, Nanomedicine"
#                         },
#                         {
#                             "id": "https://id.nlm.nih.gov/mesh/D049329",
#                             "scheme": "MeSH",
#                             "subject": "Nanostructures"
#                         },
#                         {
#                             "id": "https://id.nlm.nih.gov/mesh/D000068936",
#                             "scheme": "MeSH",
#                             "subject": "Theranostic Nanomedicine"
#                         },
#                         {
#                             "id": "https://id.nlm.nih.gov/mesh/D009369",
#                             "scheme": "MeSH",
#                             "subject": "Neoplasms"
#                         }
#                     ],
#                     "title": "Theranostic Magnetic Nanostructures (MNS) for Cancer",
#                     "version": "v1.0.0"
#                 },
#                 "parent": {
#                     "communities": {},
#                     "id": "czzcs-cas34"
#                 },
#                 "pids": {
#                     "doi": {
#                         "identifier": "10.1007/978-3-319-16555-4_3",
#                         "provider": "external"
#                     },
#                     "oai": {
#                         "identifier": "oai:prism.northwestern.edu:ptmg4-xdg64",
#                         "provider": "oai"
#                     }
#                 },
#                 "revision_id": 5,
#                 "status": "published",
#                 "updated": "2024-04-05T21:08:35.821368+00:00",
#                 "versions": {
#                     "index": 1,
#                     "is_latest": true
#                 }
#             }
#         ],
#         "total": 5836
#     },
#     "links": {
#         "next": "https://prism.northwestern.edu/api/records?page=2&size=25&sort=updated-desc",
#         "self": "https://prism.northwestern.edu/api/records?page=1&size=25&sort=updated-desc"
#     },
#     "sortBy": "updated-desc"
# }

# %%
total = response.json()['hits']['total']
print(total)
len(response_json['hits'])
# Out:
# 5836
# 2

# %%
test = response.json()['hits']
# print(type(test))
test_2 = response.json()['hits']['hits'][0]['access']
print(type(test_2))
pprint(test_2)
# Out:
# <class 'dict'>
# {'embargo': {'active': False, 'reason': None},
#  'files': 'public',
#  'record': 'public',
#  'status': 'open'}

# %%
# import requests

# ## Starting URL
# url = 'https://vtfsmghslrepo02.fsm.northwestern.edu/api/records'
# offset = 0
# size = 100
# records=[]


# while True: 
    
#     ## Python time method sleep() suspends execution for the given number of seconds 
#     time.sleep(0.1) 
    
#     print("------")
    
#     params={'size': size, 
#         'offset': offset,
# #         'page': 2, 
#         'status': 
#         'published', 
#         'sort': 'bestmatch', 
#         'all_versions': 'false', 
#         'access_token': api_key_prism
#        }

#     response = requests.get(url, params=params)
    
#     print(response.url)
#     print(response.status_code)
    
#     response_json = response.json()['hits']
# #     total = response.json()['hits']['total']

    
#     ## Did we find any records? 
#     if len(response_json["hits"]) == 0:
#         ## If no, then break and break the while loop.
#         break
    
#     ## If we did find records, add them to the list and move on to next offset
#     records.extend(response_json["hits"])
#     offset= offset + 100
   
# ## Pros: very flexible
# ## Cons: extra request, doesn't really listen to the API for the next URL

# %%
records = response.json()['hits']
print(records)

# %%
print(len(records))
print(type(records))

# %%
# prism_item_df = pd.DataFrame.from_dict(json_normalize(response_json, meta=['hits']))
# prism_item_df.head()

prism_item_df = pd.json_normalize(records, max_level = 1)
prism_item_df.head()

# %%
remove_hits_nest = prism_item_df.apply(lambda x: pd.Series(x['hits']),axis=1).stack().reset_index(level=1, drop=True).to_frame()
remove_hits_nest.rename(columns = {0:'data'}, inplace = True)
remove_hits_nest.head()

# %%
def flatten_json(nested_json, exclude=['']):
    """Flatten json object with nested keys into a single level.
        Args:
            nested_json: A nested json object.
            exclude: Keys to exclude from output.
        Returns:
            The flattened json object if successful, None otherwise.
    """
    out = {}

    def flatten(x, name='', exclude=exclude):
        if type(x) is dict:
            for a in x:
                if a not in exclude: flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(nested_json)
    return out

## https://stackoverflow.com/questions/52795561/flattening-nested-json-in-pandas-data-frame

# %%
final_df = pd.DataFrame([flatten_json(x) for x in remove_hits_nest['data']])
final_df.head()

# %%
len(final_df)

# %%
## Export file to excel, without the Pandas index, but with the header

final_df.to_excel("outputs/final_df.xlsx", index=False, header=True)

# %%
# ## Remove NESTS manually

# remove_0_nest = pd.concat([remove_hits_nest.drop(['data'], axis=1), remove_hits_nest['data'].apply(pd.Series)], axis=1, join="outer")

# ## REMOVE PIDS NESTS
# remove_pids_nest_1 = pd.concat([remove_0_nest.drop(['pids'], axis=1), remove_0_nest['pids'].apply(pd.Series)], axis=1, join="outer")
# remove_pids_nest_1.rename(columns = {'oai':'pids.oai'}, inplace = True)

# remove_pids_nest_2 = pd.concat([remove_pids_nest_1.drop(['pids.oai'], axis=1), remove_pids_nest_1['pids.oai'].apply(pd.Series)], axis=1, join="outer")
# remove_pids_nest_2.rename(columns = {'identifier':'pids.oai.identifer', 'provider': 'pids.oai.provider'}, inplace = True)


# ## REMOVE PARENT NESTS
# remove_parent_nest_1 = pd.concat([remove_pids_nest_2.drop(['parent'], axis=1), remove_pids_nest_2['parent'].apply(pd.Series)], axis=1, join="outer")
# remove_parent_nest_1.rename(columns = {'id':'parent.id', 'communities':'parent.communities'}, inplace = True)

# remove_parent_nest_2 = pd.concat([remove_parent_nest_1.drop(['parent.communities'], axis=1), remove_parent_nest_1['parent.communities'].apply(pd.Series)], axis=1, join="outer")
# remove_parent_nest_2.rename(columns = {'ids':'parent.communities.ids', 'default':'parent.communities.default'}, inplace = True)

# remove_access_nest_1 = pd.concat([remove_parent_nest_1.drop(['access'], axis=1), remove_parent_nest_1['access'].apply(pd.Series)], axis=1, join="outer")
# remove_access_nest_1.rename(columns = {'status':'access.status', 'files':'access.files', 'embargo':'access.embargo', 'record':'access.record'}, inplace = True)


# remove_parent_nest_2.head()

# %%
https://localhost:8888/callback/
